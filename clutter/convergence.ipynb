# %%
import matplotlib.pyplot as plt
import numpy as np
from mpmath import mp

# %%
data=np.load('data/bestconvergence.npy',allow_pickle=True)

# %%
N,E,D=data.transpose()

# %%
plt.scatter(N,E)
plt.plot([1,N[-1]],[-402.637263035135314,-402.637263035135314],linestyle='--')

# %%
np.real(np.array(D,dtype=complex))
# Out:
# array([0.33004453, 0.30792718, 0.31877982, 0.31206888, 0.31605325,
#        0.31715548, 0.31662436, 0.31662355, 0.31600043, 0.31253465,
#        0.31310386, 0.31288739, 0.31301735, 0.31321553, 0.31321988,
#        0.31321855, 0.31305624, 0.31301859, 0.313019  , 0.31301901,
#        0.31301901, 0.31298748, 0.31301822, 0.31374742, 0.3136686 ,
#        0.31366832, 0.3136615 , 0.31366088, 0.31365574, 0.31365924,
#        0.31364906, 0.31364906, 0.31369974, 0.31369927, 0.31369882,
#        0.31369874, 0.31369874, 0.3138038 , 0.31380424, 0.3137747 ,
#        0.31377139, 0.31377056, 0.31378542, 0.31378532, 0.3137853 ,
#        0.31376204, 0.31376189, 0.31375666, 0.31374284, 0.31377916,
#        0.31377011, 0.31376665, 0.31376695, 0.3137745 , 0.31377377,
#        0.31377378, 0.31377326, 0.31377334, 0.31377098, 0.31377077,
#        0.31376954, 0.31377115, 0.31376698, 0.31376699, 0.3137673 ,
#        0.31376711, 0.31380413, 0.31372758, 0.31370892, 0.31370744,
# ...

# %%
plt.scatter(N,np.real(np.array(D,dtype=complex)))
plt.plot([1,N[-1]],[0.3137605147,0.3137605147],linestyle='--')

# %%
plt.scatter(N[30:],E[30:])

# %%
plt.scatter(N[10:],np.real(np.array(D[10:],dtype=complex)))
