# %%
from exponential import*

# %%
params=np.load("params.npy",allow_pickle=True)
amplitudes=np.load("groundstate.npy",allow_pickle=True)

# %%
expdelta=delta(amplitudes,params)

# %%
print(HFS(expdelta))
# Out:
# 4465.619478820938577694988865748904500474248707956386684847004973254991598993273824283592875551917624

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(1000),amplitudes**2)
plt.yscale('log')

# %%
order=np.argsort(-amplitudes**2)
params=params[:,order]
amplitudes=amplitudes[order]

# %%
plt.scatter(range(1000),amplitudes**2)
plt.yscale('log')

# %%
np.save("groundstate",amplitudes,allow_pickle=True)

# %%
np.save("params.npy",params,allow_pickle=True)

# %%
print(params[:,:10].transpose())
# Out:
# [[mpf('401.82151590121321760307182557880878448486328125')
#   mpf('0.98510527909851219874326488934457302093505859375')
#   mpf('0.02951646091634495261413206890210858546197414398193359375')]
#  [mpf('402.1373667477431581573910079896450042724609375')
#   mpf('0.9783406760576258687223116794484667479991912841796875')
#   mpf('0.0215607953921913286787770402952446602284908294677734375')]
#  [mpf('289.14473677002757767695584334433078765869140625')
#   mpf('0.82364164622706115270744930967339314520359039306640625')
#   mpf('0.002678758920845813497335630160023356438614428043365478515625')]
#  [mpf('379.4053391726565678254701197147369384765625')
#   mpf('1.1246447461748143581417025416158139705657958984375')
#   mpf('0.0206830961289321789420281305638127378188073635101318359375')]
#  [mpf('304.26660401843037107028067111968994140625')
#   mpf('0.84086356097258196928834195205126889050006866455078125')
#   mpf('0.0017829944256585344465604325847607469768263399600982666015625')]
# ...
