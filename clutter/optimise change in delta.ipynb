# %%
from exponential import *
from scipy.optimize import minimize

# %%
params=np.load('params.npy',allow_pickle=True)[:,:1]

# %%
def f(x,oldexpdelta):
        
        if x[0]<=0 or x[1]<=0 or x[2]<=0:
            return 10000
        newparams=np.append(params,np.expand_dims(np.array(x),1)*mp.mpf(1),axis=1)


        subspace=Subspace(newparams.shape[1])

        subspace.set_N_func(N_func)
        subspace.set_H_func(H_func)

        subspace.set_params(newparams)

        subspace.make_N_mat()
        subspace.make_H_mat()
        subspace.find_N_eigens()
        subspace.make_Y_mat()
        subspace.make_invs_sqrt_beta_mats()
        subspace.make_P_mats()
        subspace.find_P_eigens()
        subspace.find_energy_eigenstates()
        expdelta=delta(subspace.energy_eigenstates[0],newparams)
        return -(expdelta-oldexpdelta)**2

# %%
for i in range(200):
    print()
    print(params.shape[1],"+1")
    x0=np.abs(np.array([400,1,0.02])*np.exp(np.random.normal(0,3,3)))
    print(x0)

    subspace=Subspace(params.shape[1])
    subspace.set_N_func(N_func)
    subspace.set_H_func(H_func)
    subspace.set_params(params)
    subspace.make_N_mat()
    subspace.make_H_mat()
    subspace.find_N_eigens()
    subspace.make_Y_mat()
    subspace.make_invs_sqrt_beta_mats()
    subspace.make_P_mats()
    subspace.find_P_eigens()
    subspace.find_energy_eigenstates()
    subspace.find_energy_levels()
    print("Ground State energy level:",subspace.energy_levels[0])
    #calculate the exectation of the delta 
    expdelta=delta(subspace.energy_eigenstates[0],params)
    print("the expectation of the delta:",expdelta)
    print()

    res=minimize(f,x0=x0,method='Nelder-Mead',args=(expdelta))
    params=np.append(params,np.expand_dims(np.array(res.x),1)*mp.mpf(1),axis=1)
    print(res)
# Out:
# 1 +1
# [4.08017066e+03 2.38315361e+00 6.76735320e-03]
# Ground State energy level: -402.6369442882511064163101587400076640534815731956119257569504104006216731723916477375418818758261605
# the expectation of the delta: 0.3300445271137533573509160543244392115899875427132809097288628991985224010445607263434505686871413419
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -0.0004891770863716133
#              x: [ 3.971e+02  1.625e+00  9.995e-03]
#            nit: 113
#           nfev: 205
#  final_simplex: (array([[ 3.971e+02,  1.625e+00,  9.995e-03],
#                        [ 3.971e+02,  1.625e+00,  9.995e-03],
#                        [ 3.971e+02,  1.625e+00,  9.995e-03],
#                        [ 3.971e+02,  1.625e+00,  9.995e-03]]), array([-4.892e-04, -4.892e-04, -4.892e-04, -4.892e-04]))
#
# 2 +1
# [2.02752107e+01 4.16038670e+00 8.60489733e-04]
# Ground State energy level: -402.6371748323281343796862646700552976966163628016597604786411207193523493142418903995334902553282925
# the expectation of the delta: 0.3079271790274295044664481334593237202051609074223724187020946175260188351531491829668659588873443364
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -0.00011777989368158997
#              x: [ 3.996e+02  2.568e+00  7.394e-05]
#            nit: 182
#           nfev: 322
#  final_simplex: (array([[ 3.996e+02,  2.568e+00,  7.394e-05],
#                        [ 3.996e+02,  2.568e+00,  7.394e-05],
#                        [ 3.996e+02,  2.568e+00,  7.394e-05],
#                        [ 3.996e+02,  2.568e+00,  7.394e-05]]), array([-1.178e-04, -1.178e-04, -1.178e-04, -1.178e-04]))
#
# 3 +1
# [2.23564736e+03 4.95696314e+00 3.32277758e-02]
# Ground State energy level: -402.6372464672580759858942543304878873893398483405359498870382817777940967365460448306449572540954875
# the expectation of the delta: 0.3187798235752616120254206038615690061581872521171372112884484611902731868251136045247419066713239852
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -4.5036828066286114e-05
#              x: [ 4.134e+02  7.686e-10  6.107e+00]
#            nit: 290
#           nfev: 517
#  final_simplex: (array([[ 4.134e+02,  7.686e-10,  6.107e+00],
#                        [ 4.134e+02,  2.261e-09,  6.107e+00],
#                        [ 4.134e+02,  1.692e-09,  6.107e+00],
#                        [ 4.134e+02,  2.259e-09,  6.107e+00]]), array([-4.504e-05, -4.504e-05, -4.504e-05, -4.504e-05]))
#
# 4 +1
# [1.96281208e+03 7.15067219e-01 3.85625236e-02]
# Ground State energy level: -402.6372603204664605873177986696778908942538005724081871354856973847379677393277155370313270172413589
# the expectation of the delta: 0.3120688752021711055913523229779930447088450945366044512284997270429893020594464599382926181229574588
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -1.5875276375767147e-05
#              x: [ 4.018e+02  9.851e-01  2.951e-02]
#            nit: 225
#           nfev: 402
#  final_simplex: (array([[ 4.018e+02,  9.851e-01,  2.951e-02],
#                        [ 4.018e+02,  9.851e-01,  2.951e-02],
#                        [ 4.018e+02,  9.851e-01,  2.951e-02],
#                        [ 4.018e+02,  9.851e-01,  2.951e-02]]), array([-1.588e-05, -1.588e-05, -1.588e-05, -1.588e-05]))
#
# 5 +1
# [1.72891229e+02 5.47553711e+01 2.95986370e-03]
# Ground State energy level: -402.6372978291743270706755841462201182290870642187394945348584696281742756795952435759604974582262473
# the expectation of the delta: 0.316053254247363360641456074397077122722367155334712240791332101637468376831000414125929534258598996
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -1.2149105727660645e-06
#              x: [ 3.071e+02  1.345e+02  1.242e-11]
#            nit: 288
#           nfev: 516
#  final_simplex: (array([[ 3.071e+02,  1.345e+02,  1.242e-11],
#                        [ 3.071e+02,  1.345e+02,  2.503e-11],
#                        [ 3.071e+02,  1.345e+02,  1.648e-11],
#                        [ 3.071e+02,  1.345e+02,  3.332e-11]]), array([-1.215e-06, -1.215e-06, -1.215e-06, -1.215e-06]))
#
# 6 +1
# [5.14256374e+03 1.00687040e-01 1.32870297e-03]
# Ground State energy level: -402.6372978640991307771856408142976422409790162838688393539113671104397146271697460409461748152821272
# the expectation of the delta: 0.317155484065852256540030855925841622528977936925235162842245973289521608176219157632574566180192803
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -2.820915153313549e-07
#              x: [ 4.072e+02  8.308e-01  1.888e-10]
#            nit: 276
#           nfev: 492
#  final_simplex: (array([[ 4.072e+02,  8.308e-01,  1.888e-10],
#                        [ 4.072e+02,  8.308e-01,  1.381e-09],
#                        [ 4.072e+02,  8.308e-01,  2.066e-10],
#                        [ 4.072e+02,  8.308e-01,  1.948e-09]]), array([-2.821e-07, -2.821e-07, -2.821e-07, -2.821e-07]))
#
# 7 +1
# [9.49205920e+01 2.90796421e-03 2.20684769e-05]
# Ground State energy level: -402.6373002524307822916625255732276013755472796595298839306256388132333416322633311870033193298554901
# the expectation of the delta: 0.3166243611842783641871372280182950888673597078391084663435994776756178675579889225986727084655291141
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -6.516633269861374e-13
#              x: [ 2.922e+02  1.040e-01  1.248e-12]
#            nit: 266
#           nfev: 465
#  final_simplex: (array([[ 2.922e+02,  1.040e-01,  1.248e-12],
#                        [ 2.922e+02,  1.040e-01,  4.070e-12],
#                        [ 2.922e+02,  1.040e-01,  6.944e-12],
#                        [ 2.922e+02,  1.040e-01,  2.554e-11]]), array([-6.517e-13, -6.517e-13, -6.517e-13, -6.517e-13]))
#
# 8 +1
# [3.43586518e+03 5.31410791e+00 7.22034635e-04]
# Ground State energy level: -402.6373002924291477072748584398684286279337455334266727376098234280051559594171697290100880226045413
# the expectation of the delta: 0.3166235539276110110228055594716983583548257457786029034833186311942229633856112994605524834408827039
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -3.8828692000795516e-07
#              x: [ 4.123e+02  5.805e+00  7.632e-04]
#            nit: 110
#           nfev: 212
#  final_simplex: (array([[ 4.123e+02,  5.805e+00,  7.632e-04],
#                        [ 4.123e+02,  5.805e+00,  7.632e-04],
#                        [ 4.123e+02,  5.805e+00,  7.632e-04],
#                        [ 4.123e+02,  5.805e+00,  7.632e-04]]), array([-3.883e-07, -3.883e-07, -3.883e-07, -3.883e-07]))
#
# 9 +1
# [3.83968307e+03 1.58442889e+00 8.08396598e+01]
# Ground State energy level: -402.6373008800829543132837382342901537097236167006251511544746127685098325115467022303995677322420582
# the expectation of the delta: 0.3160004271989209674691943347274540134521737143286427219207857323130583875293594558798310968575479416
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -1.2011592750942345e-05
#              x: [ 3.576e+02  1.143e-10  1.833e+02]
#            nit: 216
#           nfev: 393
#  final_simplex: (array([[ 3.576e+02,  1.143e-10,  1.833e+02],
#                        [ 3.576e+02,  2.573e-10,  1.833e+02],
#                        [ 3.576e+02,  1.933e-10,  1.833e+02],
#                        [ 3.576e+02,  3.468e-10,  1.833e+02]]), array([-1.201e-05, -1.201e-05, -1.201e-05, -1.201e-05]))
#
# 10 +1
# [1.11151302e+04 1.87599724e+00 3.25276627e-04]
# Ground State energy level: -402.6373009785595975999587927067970439773421280057189856081639654625234463584004610736510493157709241
# the expectation of the delta: 0.312534652718239579455747827728877630240020250308098230509156780379368120156434880971155903458791666
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -3.239959258618645e-07
#              x: [ 4.163e+02  8.706e+00  2.111e-03]
#            nit: 216
#           nfev: 405
#  final_simplex: (array([[ 4.163e+02,  8.706e+00,  2.111e-03],
#                        [ 4.163e+02,  8.706e+00,  2.111e-03],
#                        [ 4.163e+02,  8.706e+00,  2.111e-03],
#                        [ 4.163e+02,  8.706e+00,  2.111e-03]]), array([-3.240e-07, -3.240e-07, -3.240e-07, -3.240e-07]))
#
# 11 +1
# [1.23115494e+01 5.37480475e+00 5.65480231e-04]
# Ground State energy level: -402.6373011974074188039631053593048732189100360328887561565950316275884156877202165442477597313163173
# the expectation of the delta: 0.313103859118293078975864370811613656933667661707941623687909473828844517888320475676967178015946299
#
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: -4.6859022799036755e-08
#              x: [ 4.072e+02  8.308e-01  1.562e-10]
#            nit: 302
#           nfev: 531
#  final_simplex: (array([[ 4.072e+02,  8.308e-01,  1.562e-10],
#                        [ 4.072e+02,  8.308e-01,  3.191e-10],
#                        [ 4.072e+02,  8.308e-01,  4.260e-10],
#                        [ 4.072e+02,  8.308e-01,  4.511e-10]]), array([-4.686e-08, -4.686e-08, -4.686e-08, -4.686e-08]))
#
# 12 +1
# [10.47115226  2.15124037  0.01832363]
# Ground State energy level: -402.6373015800292286013806116232964522190845620227036006260886009646548039608122983448957931014360165
# the expectation of the delta: 0.3128873896682567360816792137554966100276845226341834421394835738233224094853438941271865764528072233
#
#        message: Maximum number of function evaluations has been exceeded.
#        success: False
#         status: 1
#            fun: -1.6888809223475805e-08
#              x: [ 4.038e+02  4.608e-02  3.558e+00]
#            nit: 333
#           nfev: 600
#  final_simplex: (array([[ 4.038e+02,  4.608e-02,  3.558e+00],
#                        [ 4.036e+02,  6.118e-02,  3.477e+00],
#                        [ 4.041e+02,  4.971e-02,  3.640e+00],
#                        [ 4.035e+02,  3.126e-01,  3.200e+00]]), array([-1.689e-08, -1.655e-08, -1.644e-08, -1.619e-08]))
#
# 13 +1
# [1.03022761e+04 4.16491149e+00 9.99159221e-04]
# Ground State energy level: -402.6373016462157767162672163907745017420048864108898788961576743026062032142077343384553048366603542
# the expectation of the delta: 0.3130173466196809511907666939687750395922256871302612251004087672665641906230877608933437444486367483
#
#        message: Maximum number of function evaluations has been exceeded.
#        success: False
#         status: 1
#            fun: -3.927839540865867e-08
#              x: [ 4.134e+02  6.076e-03  6.100e+00]
#            nit: 345
#           nfev: 600
#  final_simplex: (array([[ 4.134e+02,  6.076e-03,  6.100e+00],
#                        [ 4.134e+02,  3.926e-03,  6.103e+00],
#                        [ 4.134e+02,  6.233e-03,  6.100e+00],
#                        [ 4.134e+02,  1.008e-02,  6.096e+00]]), array([-3.928e-08, -3.927e-08, -3.923e-08, -3.922e-08]))
#
# 14 +1
# [4.72811591e+00 8.15202758e-02 1.27157024e-03]
# Ground State energy level: -402.6373017390393029310465570681828980040790790974835013273164658229799422021619183594123898580194978
# the expectation of the delta: 0.3132155343978325281127776523327040759757016556373812230630840485728607307979391509758466949626836221
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 26
#      23 print("the expectation of the delta:",expdelta)
#      24 print()
# ---> 26 res=minimize(f,x0=x0,method='Nelder-Mead',args=(expdelta))
#      27 params=np.append(params,np.expand_dims(np.array(res.x),1)*mp.mpf(1),axis=1)
#      28 print(res)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\optimize\_minimize.py:726, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     723 callback = _wrap_callback(callback, meth)
#     725 if meth == 'nelder-mead':
# --> 726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
#     729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\optimize\_optimize.py:865, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     863 if bounds is not None:
#     864     xe = np.clip(xe, lower_bound, upper_bound)
# --> 865 fxe = func(xe)
#     867 if fxe < fxr:
#     868     sim[-1] = xe
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\optimize\_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# Cell In[3], line 21, in f(x, oldexpdelta)
#      19 subspace.make_invs_sqrt_beta_mats()
#      20 subspace.make_P_mats()
# ---> 21 subspace.find_P_eigens()
#      22 subspace.find_energy_eigenstates()
#      23 expdelta=delta(subspace.energy_eigenstates[0],newparams)
#
# File c:\Users\myles\Documents\GitHub\3-particle-quantum-systems\header.py:73, in Subspace.find_P_eigens(self)
#      70 if self.verbose:
#      71   print("Finding P eigenvectors and eigenvalues.")
# ---> 73 self.P_eigenvalues, self.P_eigenvectors=mp.eigh(self.P_mats)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mpmath\matrices\eigen_symmetric.py:724, in eigh(ctx, A, eigvals_only, overwrite_a)
#     722     return ctx.eighe(A, eigvals_only = eigvals_only, overwrite_a = overwrite_a)
#     723 else:
# --> 724     return ctx.eigsy(A, eigvals_only = eigvals_only, overwrite_a = overwrite_a)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mpmath\matrices\eigen_symmetric.py:573, in eigsy(ctx, A, eigvals_only, overwrite_a)
#     571 else:
#     572     r_sy_tridiag(ctx, A, d, e, calc_ev = True)
# --> 573     tridiag_eigen(ctx, d, e, A)
#     574     return (d, A)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\mpmath\matrices\eigen_symmetric.py:474, in tridiag_eigen(ctx, d, e, z)
#     472         for w in xrange(z.rows):
#     473             f = z[w,i+1]
# --> 474             z[w,i+1] = s * z[w,i] + c * f
#     475             z[w,i  ] = c * z[w,i] - s * f
#     477 d[l] = d[l] - p
#
# File <string>:5, in __add__(self, other)
#
# KeyboardInterrupt:

# %%
np.save("altaltparams",params,allow_pickle=True)
