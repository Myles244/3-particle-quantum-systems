# %%
import numpy as np
from mpmath import mp
mp.dps=100
params=np.load("data/best100params.npy",allow_pickle=True)

# %%
for i in range(100):
    print(params[0,i],params[1,i],params[2,i])
# Out:
# 0.4034357126776166868609152516000904142856597900390625 1.50116820109443782627067776047624647617340087890625 3.442014878324453519553571823053061962127685546875
# 0.69808729293002347304764043656177818775177001953125 12.007691010054880820234757266007363796234130859375 0.016991308329007283328682120782104902900755405426025390625
# 4.15076792096768798501216224394738674163818359375 51.47662295705705304271759814582765102386474609375 0.0222309036047600543095636993484731647185981273651123046875
# 54.26611693695118532332344329915940761566162109375 1.74838249675841428398825883050449192523956298828125 0.00004697990865394695118861800864351607742719352245330810546875
# 68.0887741665715253702728659845888614654541015625 0.77276971380615611106890128212398849427700042724609375 0.00000000000006435605009614975704177783071767843315930286707260421508181025274097919464111328125
# ...

# %% [markdown]
# These are exactly the same as far as I can tell so its not a difference in the paramiters. Next things to check are the masses of the muon could different versions of scipy use different masses?
#
# The actual mass of muon and alpha particle with respect to the  from nist CODATA are
# 206.768 2827(46)
# 7 294.299 541 71(17)

# %%
from exponential import *

# %%
print(m1)
print(m2)
# Out:
# 7294.299541758158216131931720664972710951766286892221158263769971758766564872541511008487979688776645
# 206.7682827023655854273825221456907672527703016295747059648601041798739527997239756212527116568280934
